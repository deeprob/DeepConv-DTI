# %%
# !python --version
# Out:
# Python 3.7.10

# %% [markdown]
# # Train

# %%
# !python DeepConvDTI.py ./epp_examples/training_dataset/training_dti.csv ./epp_examples/training_dataset/training_compound.csv ./epp_examples/training_dataset/training_protein.csv --validation -n validation_dataset -i ./epp_examples/validation_dataset/validation_dti.csv -d ./epp_examples/validation_dataset/validation_compound.csv -t ./epp_examples/validation_dataset/validation_protein.csv -W -c 512 128 -w 10 15 20 25 30 -p 128 -f 128 -r 0.0001 -n 30 -v Convolution -l 2500 -V morgan_fp_r2 -L 2048 -D 0 -a elu -F 128 -b 256 -y 0.0001 -o ./epp_results/validation_output25.csv -m ./epp_results/model.model -e 25
# Out:
# /storage/home/d/dzb5732/work/tf_env/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /storage/home/d/dzb5732/work/tf_env/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /storage/home/d/dzb5732/work/tf_env/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %% [markdown]
# # Predict on validation

# %%
# !python predict_with_model.py ./epp_results/model.model -n predict -i ./epp_examples/validation_dataset/validation_dti.csv -d ./epp_examples/validation_dataset/validation_compound.csv -t ./epp_examples/validation_dataset/validation_protein.csv -v Convolution -l 2500 -V morgan_fp_r2 -L 2048 -W -o ./epp_results/validation_predictions25.csv
# Out:
# Using TensorFlow backend.
# /storage/home/d/dzb5732/work/tf_env/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /storage/home/d/dzb5732/work/tf_env/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /storage/home/d/dzb5732/work/tf_env/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %% [markdown]
# # Predict on test

# %%
# %%time
# !python predict_with_model.py ./epp_results/model.model -n predict -i ./epp_examples/test_dataset/kegg_dti.csv -d ./epp_examples/test_dataset/kegg_compound.csv -t ./epp_examples/test_dataset/kegg_protein.csv -v Convolution -l 2500 -V morgan_fp_r2 -L 2048 -o ./epp_results/test_predictions25.csv
# Out:
# Using TensorFlow backend.
# /storage/home/d/dzb5732/work/tf_env/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /storage/home/d/dzb5732/work/tf_env/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /storage/home/d/dzb5732/work/tf_env/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...
